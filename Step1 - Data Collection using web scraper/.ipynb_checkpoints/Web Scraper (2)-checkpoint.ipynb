# %% [markdown]
# ### Imported the necessary libraries

# %%
import bs4
import requests 
import os
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options

# %% [markdown]
# ### Defined the download function. All the images are stored in the 'Images generated' folder

# %%
def download_image(url, folder_name, num1):
    
    # write image to file
    reponse = requests.get(url)
    if reponse.status_code == 200:
        with open(os.path.join(folder_name, str(num1) + ".jpg"), 'wb') as file:
            file.write(reponse.content)
    
# create a directory to save images
folder_name = 'Images generated' # name whatever you want
if not os.path.isdir(folder_name):
    os.makedirs(folder_name)

# %% [markdown]
# ### Opened a chrome window

# %%
chromeDriverPath = r'C:\Users\birud\OneDrive - iitgn.ac.in\github\Web-Scraper\Drivers\chromedriver.exe'

# Create a ChromeOptions object instead of using the deprecated DesiredCapabilities
chrome_options = Options()

# Add any additional options you need, for example:
# chrome_options.add_argument("--headless")

# Use ChromeService instead of the deprecated Service
service = ChromeService(chromeDriverPath)

# Pass the chrome_options and service to the webdriver.Chrome constructor
driver = webdriver.Chrome(service=service, options=chrome_options)

# %% [markdown]
# ### Enter the URL below and scroll the newly opened window to its bottom most point

# %%
inp = input("Enter url: ", )
search_url = inp
driver.get(search_url)
# Out:
# Enter url: https://www.google.com/search?q=car+images&source=lnms&tbm=isch

# %% [markdown]
# ### Enter the number of images to be generated

# %%
x = int(input("Enter the number of images required : ", ))
# Out:
# Enter the number of images required : 300

# %% [markdown]
# ### Below is the code, run it

# %%
a = input("Press any key and hit enter to start : ")
# Scrolling all the way up
driver.execute_script("window.scrollTo(0, 0);")

page_html = driver.page_source
pageSoup = bs4.BeautifulSoup(page_html, 'html.parser')
containers = pageSoup.findAll('div', {'class':"isv-r PNCib ViTmJb BUooTd"}) # Choose the class based on the search_url

len_containers = len(containers)
print("Found %s image containers"%(len_containers))

# selector for first image in search_url : #islrg > div.islrc > div:nth-child(2)
# Xpath for first image in search_url : //*[@id="islrg"]/div[1]/div[1]

# Xpaths that should be ignored :
# 1) //*[@id="islrg"]/div[1]/div[25]
# 2) //*[@id="islrg"]/div[1]/div[50]

count_images_generated = 0
missed_list = []
timeout_seconds = 10  # Set the timeout value (in seconds)

# Loop 1
for i in range(1, x + 1):
    if i % 25 == 0:  # These i values can be ignored
        continue

    if count_images_generated == x:
        break
    xPath = '//*[@id="islrg"]/div[1]/div[%s]' % (i)

    # Grabbing the URL of the small preview image
    previewImageXPath = '//*[@id="islrg"]/div[1]/div[%s]/a[1]/div[1]/img' % (i)
    try:
        previewImageElement = driver.find_element('xpath', previewImageXPath)
        previewImageURL = previewImageElement.get_attribute("src")
        # clicking on the image container
        driver.find_element('xpath', xPath).click()

    except:
        missed_list.append(i)
        continue

    # Starting a while True loop to wait until we see that the URL inside the large image view is different from the preview one
    timeStarted = time.time()
    while True:
        try:
            imageElement = driver.find_element('xpath',
                                                '//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div/div[3]/div[1]/a/img[1]')
            imageURL = imageElement.get_attribute('src')

            if imageURL != previewImageURL:
                break
            else:
                # making a timeout if the full res image can't be loaded
                currentTime = time.time()

                if currentTime - timeStarted > timeout_seconds:
                    print("Timeout! Exiting the loop.")
                    break

        except Exception as e:
            print(f"Error: {e}. Couldn't retrieve full res image URL. Continuing to the next one.")
            break  # Continue to the next iteration if an error occurs

    # Try to download the image
    try:
        download_image(imageURL, folder_name, count_images_generated)
        print("Downloaded element %s. URL: %s" % (i, imageURL))
        count_images_generated += 1

    except Exception as e:
        print(f"Error: {e}. Couldn't download the image {i}, continuing downloading the next one.")

    time.sleep(1)  # Add a small delay to avoid overloading the server

  
    # Loop 2
driver.execute_script("window.scrollTo(0, 0);")

page_html = driver.page_source
pageSoup = bs4.BeautifulSoup(page_html, 'html.parser')
containers = pageSoup.findAll('div', {'class':"isv-r PNCib ViTmJb BUooTd"}) # Choose the class based on the search_url
for i in missed_list:
    missed_count = 0
    if count_images_generated == x:
        break

    for j in range(1, x + 1):
        if count_images_generated == x:
            break

        xPath = '//*[@id="islrg"]/div[1]/div[%s]/div[%s]' % (i, j)

        # Grabbing the URL of the small preview image
        previewImageXPath = '//*[@id="islrg"]/div[1]/div[%s]/div[%s]/a[1]/div[1]/img' % (i, j)
        try:
            previewImageElement = driver.find_element('xpath', previewImageXPath)
            previewImageURL = previewImageElement.get_attribute("src")

            # clicking on the image container
            driver.find_element('xpath', xPath).click()

        except:
            missed_count += 1
            if missed_count > 50:
                break

            continue

        # Starting a while True loop to wait until we see that the URL inside the large image view is different from the preview one
        timeStarted = time.time()
        while True:

            try:
                imageElement = driver.find_element('xpath',
                                                    '//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div/div[3]/div[1]/a/img[1]')
                imageURL = imageElement.get_attribute('src')

                if imageURL != previewImageURL:
                    break
                else:
                    # making a timeout if the full res image can't be loaded
                    currentTime = time.time()

                    if currentTime - timeStarted > timeout_seconds:
                        print("Timeout! Exiting the loop.")
                        break

            except Exception as e:
                print(f"Error: {e}. Couldn't retrieve full res image URL. Continuing to the next one.")
                break  # Continue to the next iteration if an error occurs

        # Try to download the image
        try:
            download_image(imageURL, folder_name, count_images_generated)
            print("Downloaded element [%s, %s]. URL: %s" % (i, j, imageURL))
            count_images_generated += 1

        except Exception as e:
            print(f"Error: {e}. Couldn't download the image {i}, {j}, continuing downloading the next one")

        time.sleep(1)  # Add a small delay to avoid overloading the server

if x == count_images_generated:
    print("Target Reached")
else:
    print("There is some issue, scroll down the page and run code again")
# Out:
# Press any key and hit enter to start : a
# Found 48 image containers
# Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="Sva75c"]/div[2]/div[2]/div[2]/div[2]/c-wiz/div/div/div/div/div[3]/div[1]/a/img[1]"}
#   (Session info: chrome=120.0.6099.200); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF611412142+3514994]
# 	(No symbol) [0x00007FF611030CE2]
# 	(No symbol) [0x00007FF610ED76AA]
# 	(No symbol) [0x00007FF610F21860]
# 	(No symbol) [0x00007FF610F2197C]
# 	(No symbol) [0x00007FF610F64EE7]
# 	(No symbol) [0x00007FF610F4602F]
# 	(No symbol) [0x00007FF610F628F6]
# 	(No symbol) [0x00007FF610F45D93]
# 	(No symbol) [0x00007FF610F14BDC]
# 	(No symbol) [0x00007FF610F15C64]
# 	GetHandleVerifier [0x00007FF61143E16B+3695259]
# 	GetHandleVerifier [0x00007FF611496737+4057191]
# 	GetHandleVerifier [0x00007FF61148E4E3+4023827]
# 	GetHandleVerifier [0x00007FF6111604F9+689705]
# 	(No symbol) [0x00007FF61103C048]
# 	(No symbol) [0x00007FF611038044]
# 	(No symbol) [0x00007FF6110381C9]
# 	(No symbol) [0x00007FF6110288C4]
# 	BaseThreadInitThunk [0x00007FFA328C257D+29]
# 	RtlUserThreadStart [0x00007FFA33F0AA58+40]
# . Couldn't retrieve full res image URL. Continuing to the next one.
# Error: name 'imageURL' is not defined. Couldn't download the image 1, continuing downloading the next one.
# Downloaded element 2. URL: https://img.freepik.com/free-photo/luxurious-car-parked-highway-with-illuminated-headlight-sunset_181624-60607.jpg
# Downloaded element 3. URL: https://images.unsplash.com/photo-1605559424843-9e4c228bf1c2?q=80&w=1000&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8MTF8fGNhcnN8ZW58MHx8MHx8fDA%3D
# Downloaded element 4. URL: https://images.pexels.com/photos/35967/mini-cooper-auto-model-vehicle.jpg?cs=srgb&dl=pexels-pixabay-35967.jpg&fm=jpg
# Downloaded element 5. URL: https://imageio.forbes.com/specials-images/imageserve/5d35eacaf1176b0008974b54/2020-Chevrolet-Corvette-Stingray/0x0.jpg?format=jpg&crop=4560,2565,x790,y784,safe&width=960
# Downloaded element 6. URL: https://images.pexels.com/photos/1545743/pexels-photo-1545743.jpeg?cs=srgb&dl=pexels-yurii-hlei-1545743.jpg&fm=jpg
# Downloaded element 7. URL: https://cdni.autocarindia.com/utils/imageresizer.ashx?n=https://cms.haymarketindia.net/model/uploads/modelimages/Lamborghini-Revuelto-190920231426.jpg&w=872&h=578&q=75&c=1
# Downloaded element 8. URL: https://cdni.autocarindia.com/utils/imageresizer.ashx?n=https://cms.haymarketindia.net/model/uploads/modelimages/Hyundai-Grand-i10-Nios-200120231541.jpg&w=872&h=578&q=75&c=1
# Downloaded element 9. URL: https://i.pinimg.com/736x/f7/cf/ea/f7cfeada56951abeb13ebedece73f3f8.jpg
# Downloaded element 10. URL: https://images.unsplash.com/photo-1570294646112-27ce4f174e38?ixlib=rb-4.0.3&q=85&fm=jpg&crop=entropy&cs=srgb
# Downloaded element 11. URL: https://img.freepik.com/premium-photo/bangkok-thailand-08082022-lamborghini-luxury-super-car-fast-sports-premium-lighting-background-3d-illustration_67092-1599.jpg
# Downloaded element 12. URL: https://media.istockphoto.com/id/1493574434/photo/car-rushes-along-the-highway-at-sunset-low-angle-side-view.jpg?b=1&s=170667a&w=0&k=20&c=X34OZS-4XQ10buM6BuE5xQpYuvXMWwOoodvU5NtHzgc=
# Downloaded element 13. URL: https://i.pinimg.com/736x/bd/78/4b/bd784bbb8df3189579511325ba82f0b3.jpg
# Downloaded element 14. URL: https://imgd.aeplcdn.com/370x208/n/cw/ec/141867/nexon-exterior-right-front-three-quarter-71.jpeg?isig=0&q=80
# Downloaded element 15. URL: https://www.easylinedrawing.com/wp-content/uploads/2019/07/car_drawing_tutorial.png
# Downloaded element 16. URL: https://images.pexels.com/photos/170811/pexels-photo-170811.jpeg?cs=srgb&dl=pexels-mike-bird-170811.jpg&fm=jpg
# Downloaded element 17. URL: https://img.freepik.com/free-photo/modern-sports-car-speeds-through-dark-curve-generative-ai_188544-9136.jpg
# Downloaded element 18. URL: https://akm-img-a-in.tosshub.com/businesstoday/images/story/202002/lamborghini_660_140220101539.jpg
# Downloaded element 19. URL: https://www.linearity.io/blog/content/images/2023/06/how-to-create-a-car-NewBlogCover.png
# Downloaded element 20. URL: https://www.topgear.com/sites/default/files/2022/07/13.jpg
# Downloaded element 21. URL: https://stimg.cardekho.com/images/carexteriorimages/630x420/Mercedes-Benz/GLA/10849/1690447163011/front-left-side-47.jpg?impolicy=resize&imwidth=480
# Downloaded element 22. URL: https://imgd.aeplcdn.com/600x337/n/cw/ec/44709/fortuner-exterior-right-front-three-quarter-20.jpeg?isig=0&q=80
# Downloaded element 23. URL: https://static.autox.com/uploads/cars/2023/01/hyundai-grand-i10-nios-facelift3.jpg
# Timeout! Exiting the loop.
# Downloaded element 24. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTg8G_eH0txiZpizOQQ5c6ei85avp4z-0oZaw&usqp=CAU
# Downloaded element 26. URL: https://www.autocar.co.uk/sites/autocar.co.uk/files/styles/gallery_slide/public/images/car-reviews/first-drives/legacy/rolls_royce_phantom_top_10.jpg?itok=XjL9f1tx
# Downloaded element 27. URL: https://www.bentleymotors.com/content/dam/bentley/Master/Homestage%20Tiles/Batur_16_1024x512%20Rear34_v11a.jpg/_jcr_content/renditions/original.image_file.700.350.file/Batur_16_1024x512%20Rear34_v11a.jpg
# Downloaded element 28. URL: https://cdn.pixabay.com/photo/2012/04/12/23/48/car-30990_640.png
# Downloaded element 29. URL: https://images.unsplash.com/photo-1550355291-bbee04a92027?q=80&w=1000&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8MTZ8fGNhcnxlbnwwfHwwfHx8MA%3D%3D
# Downloaded element 30. URL: https://www.hyundai.com/content/dam/hyundai/in/en/data/find-a-car/i20/Highlights/pc/i20_Modelpc.png
# Downloaded element 31. URL: https://hips.hearstapps.com/hmg-prod/images/dw-burnett-pcoty22-8260-1671143390.jpg?crop=0.668xw:1.00xh;0.184xw,0&resize=640:*
# Downloaded element 32. URL: https://images.assettype.com/fortuneindia%2F2021-01%2Fd14fb40c-4739-4da8-96d7-4efd332715d5%2FAUDI_S5.jpg?w=1250&q=60
# Downloaded element 33. URL: https://stimg.cardekho.com/images/carexteriorimages/630x420/Lamborghini/Revuelto/9770/1680237730530/front-left-side-47.jpg?imwidth=420&impolicy=resize
# Downloaded element 34. URL: https://cdn.motor1.com/images/mgl/JO94P6/481:0:2878:2160/most-expensive-cars-in-the-world.webp
# Downloaded element 35. URL: https://robbreport.com/wp-content/uploads/2023/02/30-1.jpg?w=1000
# Downloaded element 36. URL: https://images.pexels.com/photos/3729464/pexels-photo-3729464.jpeg?cs=srgb&dl=pexels-mike-bird-3729464.jpg&fm=jpg
# Downloaded element 37. URL: https://cars.tatamotors.com/content/dam/tml/pv/products/tiago/year-2023/ice/promoting-vc/lifestyle/home-hero-tiago-1.jpg
# Downloaded element 38. URL: https://carwow-uk-wp-3.imgix.net/18015-MC20BluInfinito-scaled-e1666008987698.jpg
# Downloaded element 39. URL: https://img.freepik.com/free-photo/sports-car-races-through-dark-blurred-motion-generative-ai_188544-12490.jpg?size=626&ext=jpg&ga=GA1.1.1412446893.1704499200&semt=ais
# Downloaded element 40. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS0bWuKCz4gtbALIq4CBCVK47PHCGoSFg1Fzg&usqp=CAU
# Downloaded element 41. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQBv3JZ9RZUtFuLcFsfBm8jaqDeJw5UyIuhRQ&usqp=CAU
# Downloaded element 42. URL: https://static.theprint.in/wp-content/uploads/2023/01/Iyer.jpg
# Downloaded element 43. URL: https://robbreport.com/wp-content/uploads/2023/09/RR_50_Most_Expensive_Cars_You_Can_Buy_Right_Now_lead.jpg?w=1000
# Downloaded element 44. URL: https://imgd.aeplcdn.com/642x336/n/cw/ec/54399/swift-exterior-right-front-three-quarter-64.jpeg?isig=0&q=80
# Downloaded element 45. URL: https://images.unsplash.com/photo-1494976388531-d1058494cdd8?q=80&w=1000&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8Nnx8Y2FyfGVufDB8fDB8fHww
# Downloaded element 46. URL: https://m.economictimes.com/thumb/height-450,width-600,imgsize-92902,msid-96559100/the-rimac-nevera-is-now-the-fastest-electric-car-in-the-world-image-rimac.jpg
# Downloaded element 47. URL: https://www.shutterstock.com/image-photo/new-car-sedan-type-modern-600nw-2295122863.jpg
# Downloaded element 48. URL: https://i0.wp.com/gomechanic.in/blog/wp-content/uploads/2020/09/10-Things-you-should-never-do-in-a-new-car-01-e1602914262125.jpg?fit=1200%2C617&ssl=1
# Downloaded element 49. URL: https://media.istockphoto.com/id/970371780/photo/an-attractive-woman-in-a-car-holds-a-car-key-in-her-hand.jpg?s=612x612&w=0&k=20&c=xYMb4NCQ3hCUAAXW-TDucSDOwY2kxy2mK3qFp7E_cgQ=
# Downloaded element [51, 1]. URL: https://imgd-ct.aeplcdn.com/1200x900/n/cw/ec/46994/jaguar-f-type-right-front-three-quarter18.jpeg?q=80
# Downloaded element [51, 2]. URL: https://www.carlelo.com/laravel/public/uploads/model/1650079167.webp
# Downloaded element [51, 3]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTHvptcldb2Hb9RA9_QE9Jg4PTsUQplGvj0Aw&usqp=CAU
# Downloaded element [51, 4]. URL: https://staranddaisy.in/wp-content/uploads/2023/03/lfcbdq1588_new_white_1.jpg
# Downloaded element [51, 5]. URL: https://www.mercedes-benz.co.in/content/india/en/passengercars/_jcr_content/root/responsivegrid/simple_teaser_115569/simple_teaser_item_c.component.damq2.3383738240293.jpg/.A-Class-Image.jpg
# Downloaded element [51, 6]. URL: https://stimg.cardekho.com/images/carexteriorimages/630x420/Mahindra/Thar/10745/1697697308167/front-left-side-47.jpg?imwidth=420&impolicy=resize
# Downloaded element [51, 7]. URL: https://cdn.motor1.com/images/mgl/g440ng/s3/rimac-nevera.jpg
# Downloaded element [51, 8]. URL: https://media.istockphoto.com/id/1273682054/photo/car-service-worker-applying-nano-coating-on-a-car-detail.jpg?s=612x612&w=0&k=20&c=w2YoGPnv24lcITfiH7jnTYLAj9xCXUrlbHn33lxcd2U=
# Downloaded element [51, 9]. URL: https://static.toiimg.com/photo/80387978.cms
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)). Couldn't download the image 51, 10, continuing downloading the next one
# Downloaded element [51, 11]. URL: https://img.freepik.com/free-photo/sports-car-driving-asphalt-road-night-generative-ai_188544-8052.jpg?size=626&ext=jpg&ga=GA1.1.1412446893.1704499200&semt=sph
# Downloaded element [51, 12]. URL: https://www.lamborghini.com/sites/it-en/files/DAM/lamborghini/facelift_2019/homepage/families-gallery/2023/revuelto/revuelto_m.png
# Downloaded element [51, 13]. URL: https://d2m3nfprmhqjvd.cloudfront.net/blog/20231103174155/new-Tata-Safari.jpg
# Downloaded element [51, 14]. URL: https://www.hyundai.com/content/dam/hyundai/in/en/data/find-a-car/Verna/Highlights/pc/verna_model.png
# Downloaded element [51, 15]. URL: https://cdni.autocarindia.com/Utils/ImageResizer.ashx?n=https://cdni.autocarindia.com/ExtraImages/20230512054112_luxury_cars_.jpg&w=700&q=90&c=1
# Downloaded element [51, 16]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQxAqq6fpZY1P_z8xsqcmr4OTJ5WD36_RdAwQ&usqp=CAU
# Downloaded element [51, 17]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTqxNwDI3t78koemJU-0JEM0HYOtfz2vWT5mQ&usqp=CAU
# Downloaded element [51, 18]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRZEPX5e9fb1NqflfbAtnM66EbaNkXb_fcfQw&usqp=CAU
# Downloaded element [51, 19]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS40KS57j4pCUOgjRNBjPOsIJQ_m_fg2NnklA&usqp=CAU
# Downloaded element [51, 20]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSsIubCaJ7d52-88bS6uMzOuaB4LJHRBdixGw&usqp=CAU
# Downloaded element [51, 21]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT2O7YUF4C95ascX3bbmV9Zm-a4xtIgqpPHBg&usqp=CAU
# Downloaded element [51, 22]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRLJARnL0KWT4UkTtVS__-oY9VlAk5DTMFXmA&usqp=CAU
# Downloaded element [51, 23]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTeC7j33q6PdKQHnUlVyxALcxWZuc150CLvXg&usqp=CAU
# Downloaded element [51, 24]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ4EGb-50xKrnlXL6y1GB6ZawewAclwOi1rCQ&usqp=CAU
# Downloaded element [51, 26]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTLsnOSahBI-M4BvQt7R35jR6UbSXQIu3_YGw&usqp=CAU
# Downloaded element [51, 27]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS-ruDhimX71VtwMSDShvKGMT_PxDRoI01sOg&usqp=CAU
# Downloaded element [51, 28]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRk0b8FZLoQiyMs1TMC_Vsn1HZ66LWegnCPtw&usqp=CAU
# Downloaded element [51, 29]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTcWjflqXBMmxfn4bO70NpjWYWXHShRU7DYkA&usqp=CAU
# Downloaded element [51, 30]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRFfv5VdDYrotF0sAus3Hv4-gWaXjjvIVIzXg&usqp=CAU
# Downloaded element [51, 31]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTwES0M2BTt0gkn53MqOlDw_brXariOjicZKw&usqp=CAU
# Downloaded element [51, 32]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT7kS0uTo2cqYBMXlD0frOlEpGvQ5XFXXxUlA&usqp=CAU
# Downloaded element [51, 33]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQuxSDBvYFtgSCbjz9GI1Q3xP5QOGDuCpm81A&usqp=CAU
# Downloaded element [51, 34]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRx4I9Y8tOB6r7VEH9DfBsqc_EW18TB53Obrw&usqp=CAU
# Downloaded element [51, 35]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNwcTTew6SrG-BDisWgqwfpLKfg8Ro8m1bTQ&usqp=CAU
# Downloaded element [51, 36]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTnWtL4pYVUlx7MWuArIv8jEg9KCDiTf0U-Bg&usqp=CAU
# Downloaded element [51, 37]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQlxUpW7s25AqkIoer24TZA50kLQesLE2BVHw&usqp=CAU
# Downloaded element [51, 38]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRK7QnatXIO1w6JGqnDyTpO4wGEydWKgRoKgw&usqp=CAU
# Downloaded element [51, 39]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSYrEf9XNy6IfsUCYA1d_r5iusckr9s0j-iVQ&usqp=CAU
# Downloaded element [51, 40]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSgVVQ2fl6kk1X6ZScN0FjNPNjuSpCJLrz7sg&usqp=CAU
# Downloaded element [51, 41]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS-Te1z4QufwdqH2IW5R33YQ1ELS45NZfWfCA&usqp=CAU
# Downloaded element [51, 42]. URL: https://cdn.pixabay.com/photo/2015/01/20/11/09/black-605334_640.jpg
# Downloaded element [51, 43]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ1KsVLrv_Jh0kSBb-7rc9ZM4VeKcliw14bXg&usqp=CAU
# Downloaded element [51, 44]. URL: https://media.zigcdn.com/media/model/2021/May/v8_360x240.jpg
# Downloaded element [51, 45]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT9rmhmUwYreci1t1__n2_8H0fnAyqHpmTYRA&usqp=CAU
# Downloaded element [51, 46]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRtvdTKH5w68VQiMY6O3qF7CR9k87N8tlqG4g&usqp=CAU
# Downloaded element [51, 47]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT6Pe8j9jnCkPnJEBej_PntiVKKPZqiJsz66g&usqp=CAU
# Downloaded element [51, 48]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ8pQiq24rlXyfPwJ1utV315snPHKi8mGEwvA&usqp=CAU
# Downloaded element [51, 49]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSxOey529V1gVi81xvAQWMHV06YQQ4nXfPjoQ&usqp=CAU
# Downloaded element [51, 51]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRxn1byqdJgkQWwDsrIKawjoVRDUZfRRMTVmg&usqp=CAU
# Downloaded element [51, 52]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-0L7I1sMnb4DG4d-SgccrdFu26rkPmpK9-Q&usqp=CAU
# Downloaded element [51, 53]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ9LVrHCcx5Qd9T4K33yVDHLjSUGCVtcTtYTCDb8Bku4QIpFFabXUMTuTcjus0E7J4TFRU&usqp=CAU
# Downloaded element [51, 54]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS2ixzvDvLGoPJUy-Pyb67moGuFTrRfQOnHkw&usqp=CAU
# Downloaded element [52, 1]. URL: https://i.pinimg.com/originals/10/66/46/1066461b5705cbd2a4a074dfa7df12e9.jpg
# Timeout! Exiting the loop.
# Downloaded element [52, 2]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRTru23BN6QGt56zr7gu6C16r4ZTQHbOlptJ1d6GugoDJakXTmXmPm-_vNgNCg19OwBHpI&usqp=CAU
# Downloaded element [52, 3]. URL: https://autobest.co.in/uploads/blog/347245978613.jpg
# Downloaded element [52, 4]. URL: https://static.toiimg.com/thumb/msid-103888764,width-1070,height-580,imgsize-35214,resizemode-75,overlay-toi_sw,pt-32,y_pad-40/photo.jpg
# Downloaded element [52, 5]. URL: https://imgd.aeplcdn.com/370x208/n/cw/ec/132513/7-series-exterior-right-front-three-quarter-3.jpeg?isig=0&q=80
# Downloaded element [52, 6]. URL: https://www.team-bhp.com/sites/default/files/verna-drive-banner.jpg
# Downloaded element [52, 7]. URL: https://www.shutterstock.com/image-vector/realistic-vector-red-car-gradients-260nw-2271536365.jpg
# Downloaded element [52, 8]. URL: https://stimg.cardekho.com/images/car-images/large/Maruti/Swift/10402/1688189645237/224_Pearl-Metallic-Midnight-Blue_0e376c.jpg
# Downloaded element [52, 9]. URL: https://robbreport.com/wp-content/uploads/2022/11/11-w-Utopia_1.jpg?w=1000
# Downloaded element [52, 10]. URL: https://images.pexels.com/photos/210019/pexels-photo-210019.jpeg?cs=srgb&dl=pexels-pixabay-210019.jpg&fm=jpg
# Downloaded element [52, 11]. URL: https://www.mynrma.com.au/-/media/2021-best-cars-ford-mustang-hero-mobile.jpg?h=360&w=640&hash=429e38fbefc48878a54438c21c98f863
# Downloaded element [52, 12]. URL: https://cdn.group.renault.com/ren/in/triber-my23---may-new-assets/Mobile.jpg.ximg.xsmall.jpg/39f9985baf.jpg
# Downloaded element [52, 13]. URL: https://www.topgear.com/sites/default/files/2022/07/6_0.jpg
# Downloaded element [52, 14]. URL: https://spn-sta.spinny.com/spinny-web/static-images/assets/images/pages/HomePage/components/TopBannerV2/assets/sellcar_v7.jpeg?w=360&dpr=1.0
# Downloaded element [52, 15]. URL: https://hips.hearstapps.com/hmg-prod/images/bmw-vision-neue-klasse-concept-car5-64ecd9b81229e.jpg?crop=0.669xw:1.00xh;0.280xw,0&resize=640:*
# Downloaded element [52, 16]. URL: https://wlt-p-001.sitecorecontenthub.cloud/api/public/content/0fdac51ab4f14c059952cb8333c7ee51?v=67d6e3db
# Downloaded element [52, 17]. URL: https://cdn.jdpower.com/Average%20Weight%20Of%20A%20Car.jpg
# Downloaded element [52, 18]. URL: https://content-images.carmax.com/qeontfmijmzv/7ou0KbDX3UIgor1VY7iZiS/1c92f43c52d34a9fe6bc0843e59e7aba/2023_Acura_TLX_EVOX.jpg
# Downloaded element [52, 19]. URL: https://www.hondacarindia.com/_next/image?url=https%3A%2F%2Fcdn2.hondacarindia.com%2Fhome%2Fbanner%2FSpecial%20Occasions_Mobile.jpg&w=3840&q=75
# Downloaded element [52, 20]. URL: https://images.unsplash.com/photo-1580273916550-e323be2ae537?q=80&w=1000&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8MXx8Ym13JTIwY2FyfGVufDB8fDB8fHww
# Downloaded element [52, 22]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ--x2m-sRtPm6MIPvYiTPFxAGuG9H5EgPvDg&usqp=CAU
# Downloaded element [52, 23]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRfV60GZWYJMQmoORIW6UbMhXDYRLs-OFOdqw&usqp=CAU
# Downloaded element [52, 24]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTC_y6XZOr0d0KV9rG0m67wLcjK-mE5NpLOJQ&usqp=CAU
# Downloaded element [52, 25]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSQzF_FfKio3csWmc9Nhbj8VrtUxGzJWbFM0A&usqp=CAU
# Downloaded element [52, 26]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQSO_h2ZLUw24ajTHU2go8fr4twHrEBvWimcQ&usqp=CAU
# Downloaded element [52, 27]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSO1q5iuu6wJJpVVV5U4Gr_SvpPwdiiYzXGcg&usqp=CAU
# Downloaded element [52, 28]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR_O1krFDBcBOCqRl6AeDsQgifjXPACsii6GQ&usqp=CAU
# Downloaded element [52, 29]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRwN7q0dZ3rhYSSnP0Hmj2ssBKxyWwQPpgeGw&usqp=CAU
# Downloaded element [52, 30]. URL: https://cdn.pixabay.com/photo/2020/09/06/07/37/car-5548242_1280.jpg
# Downloaded element [52, 31]. URL: https://upload.wikimedia.org/wikipedia/commons/4/47/VW_K%C3%A4fer_blue_1956_vr_TCE.jpg
# Downloaded element [52, 32]. URL: https://img.etimg.com/thumb/msid-102872483,width-640,resizemode-4/industry/auto/cars-uvs/in-pics-the-worlds-most-expensive-car-rolls-royce-la-rose-noire-droptail/la-rose-noire.jpg
# Downloaded element [52, 33]. URL: https://www.carandbike.com/_next/image?url=https%3A%2F%2Fimages.carandbike.com%2Fcar-images%2Fbig%2Fhonda%2Famaze%2Fhonda-amaze.jpg%3Fv%3D40&w=640&q=75
# Downloaded element [52, 34]. URL: https://images.hindustantimes.com/auto/img/2021/12/28/600x338/Indian_cars_1640662074513_1640662081298.jpg
# Downloaded element [52, 35]. URL: https://i0.wp.com/gomechanic.in/blog/wp-content/uploads/2022/02/10-cheapest-4-5-star-cars-blog-post.webp?fit=1000%2C500&ssl=1
# Downloaded element [52, 36]. URL: https://staranddaisy.in/wp-content/uploads/2023/03/ifc_ft938_green_new_4.jpg
# Downloaded element [52, 37]. URL: https://www.motortrend.com/uploads/2022/08/2022-Bugatti-Chiron-Super-Sport-2-1.jpg?fit=around%7C875:492
# Downloaded element [52, 38]. URL: https://cars.tatamotors.com/content/dam/tml/pv/products/altroz/year-2023/ice/promoting-vc/lifestyle/home-hero-altroz-1.jpg
# Downloaded element [52, 39]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRVJo0dwT5maXpjaeuZaVh5fgKLMaAS-0BKBg&usqp=CAU
# Downloaded element [52, 40]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNss58LFK9PybDO3YAM6j1ooY_VNbdDxodaQ&usqp=CAU
# Downloaded element [52, 41]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpkhWfYatDKH3aSqx2dzgt3I6e4BxeZtR8Hw&usqp=CAU
# Downloaded element [52, 42]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQrDoqntkrbdcPwmPWjeZk0ZyVr-MskVd1FRw&usqp=CAU
# Downloaded element [52, 43]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSpCDqpSbpsjfn-3pYsvSlzq0YENe6UZogNZg&usqp=CAU
# Downloaded element [52, 44]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTDMJhBXi_o5KjEsRMvFRFE1aUDs5rwiUkauA&usqp=CAU
# Downloaded element [52, 45]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTaxTXrwam02kzKKNDabGkCkRRdYs_siK4XHQ&usqp=CAU
# Downloaded element [52, 47]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSyq0v4cAx7NtMtxOyE140XSL_ELu9diPyfsw&usqp=CAU
# Downloaded element [52, 48]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSO39IEApbXZ0YBAuil37t1rkJZqMJVVz1Nwg&usqp=CAU
# Downloaded element [52, 49]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQzho2DTttxYcP-kIOZZg5eB1ZqGZtd2G8o-Q&usqp=CAU
# Downloaded element [52, 50]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSh2tSCp2BUjjM9kRmnL_f0gYCiq54OX0Mfgg&usqp=CAU
# Downloaded element [52, 51]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQPKn_tNU-uiedX3_bY40bvo5ifM6aS1uqkKA&usqp=CAU
# Downloaded element [52, 52]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRzsLvZDGFaRz0rSTHbElc9WbPD5VbVMVtQQw&usqp=CAU
# Downloaded element [52, 53]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSdCeeJcaOqOBB0XzFfxLLiGz8zVU9bbhsX8w&usqp=CAU
# Downloaded element [52, 54]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQcvJ4kiuV1r-o-t5ExG6FGQffKMeLf7ozK3w&usqp=CAU
# Downloaded element [52, 55]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSCzE6BU0Jv_5OBl6XeEHtWHGr5ul-FGtNEJA&usqp=CAU
# Downloaded element [52, 56]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS_mnnHrnOdRbUVXS_jGzd--xHlh6QqdjLJJA&usqp=CAU
# Downloaded element [52, 57]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTU01lPL9o79KclxYC5h8I8_CtDTbfd6_FeOw&usqp=CAU
# Downloaded element [52, 58]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTNbRNCwoaYFPDyP83Kx2ErWXolEu3xOQDVsA&usqp=CAU
# Downloaded element [52, 59]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQx6Y26YOjgzDm8RNQL3V0oa3ZqrYhfHmnLyA&usqp=CAU
# Downloaded element [52, 60]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTKYagiNHYZWOE8OIbqLRuWCFasBczxmxiLFQ&usqp=CAU
# Downloaded element [52, 61]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSAjjy9Oj1Zg0BOJ1wEykrEYR-vUSzBu3RjaQ&usqp=CAU
# Downloaded element [52, 62]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRgCiVD5Q0eJU77gUW4qEoaN9zSzNB0Bd5blQ&usqp=CAU
# Downloaded element [52, 63]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSCP_5UxdLBiIEfEBLR8Fk1YPaLJTkjT_fBfg&usqp=CAU
# Downloaded element [52, 64]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSXL2aFuEUqZFyiw486DqnqSXXq_Zm4DvBZjg&usqp=CAU
# Downloaded element [52, 65]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS9jX-UjeE-mwgahdXymx1UIoPMe_x4C-LwZw&usqp=CAU
# Downloaded element [52, 66]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQKkEuyUCzgxppp0s2syK56ACouZrgULo38nQ&usqp=CAU
# Downloaded element [52, 67]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSqU0oGGTqnhQAKjtk8ANVPrk6eQH62Cslqrg&usqp=CAU
# Downloaded element [52, 68]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTqlgD1z9gwkvpu03IyPNTeiLd8-x6a5-dUwg&usqp=CAU
# Downloaded element [52, 69]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRPFoRwZfwqMwgKaV8tO8i8wu4EIIoo9oiqdg&usqp=CAU
# Downloaded element [52, 70]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTAtusKiLWlXPUcP0zAK8ZshiUjkvkjOr9JmA&usqp=CAU
# Downloaded element [52, 72]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRl-vrCm1wWVc-CjxNLHhDwnrCemkLls8cCbA&usqp=CAU
# Downloaded element [52, 73]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQXJarSxqiZL0k87qlG9zubndbUmItquxbJPA&usqp=CAU
# Downloaded element [52, 74]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQf_leMq_NbGkv2_yq5tKWqsVg1xq3gwX1VVQ&usqp=CAU
# Downloaded element [52, 75]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRhgC2P5cHNt_hWermKnYI3Nsx3BUatcwfCNw&usqp=CAU
# Downloaded element [52, 76]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRipqIMcjSXbenjR2RZQnNVjvqcmTdT7sbGag&usqp=CAU
# Downloaded element [52, 77]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQKdPTykgSoFgTWKNFOxJlFHHQYGBV_odJSDA&usqp=CAU
# Downloaded element [52, 78]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQsJyvLffgwxpgkpowTwOcCtVKkSnU32kDAqQ&usqp=CAU
# Downloaded element [52, 79]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQc1Fk4M8Xi6hf56q9L_OG2pCoUGPgUod8GRA&usqp=CAU
# Downloaded element [52, 80]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQfhyMuCIsHsKGIndNLJ62-As-eymoJ5WuGLQ&usqp=CAU
# Downloaded element [52, 81]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRJ4cAyGwx9ClJmDWzsfZBjnBHZClSNOMKH_A&usqp=CAU
# Downloaded element [52, 82]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRFSVvWqYEfEZj2Jo3cAlbq3TE4hTUb3RwvGA&usqp=CAU
# Downloaded element [52, 83]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTKHgjf5ELB1ssV4y8o3FrLX1fcEW-62w7iDA&usqp=CAU
# Downloaded element [52, 84]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRYRz6vjJxEnn3_5QhO6KWjht9H4wwLtA9olw&usqp=CAU
# Downloaded element [52, 85]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQlxaMGurORPPA6tofD_Vz5t6RIHaZMr9Wd6w&usqp=CAU
# Downloaded element [52, 86]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS8I8UkgdjeC2SnvC7EnZr1-99WfhRJw385Ug&usqp=CAU
# Downloaded element [52, 87]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS2NxSigMJHoNuAkLJ4scUtl_1DCrUzR7EUJQ&usqp=CAU
# Downloaded element [52, 88]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSvMuOzcuo5xiSAvlmwaIDyenDBIpTWeUZigg&usqp=CAU
# Downloaded element [52, 89]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSn6xcluuHc8xcC6391h_aWKAkSyZJA08mhfw&usqp=CAU
# Downloaded element [52, 90]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT1Lwm7yI4El1Z5pcFqoaCHaeSTXFAY-UlAEQ&usqp=CAU
# Downloaded element [52, 91]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSJVLy1PoXmGlk2CeUPZG_4qa11oFOba05wFA&usqp=CAU
# Downloaded element [52, 92]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSHv-xfv6x6I502rtArODqdVFeTagXd1g4Wtw&usqp=CAU
# Downloaded element [52, 93]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQsQF4aDNAnAlynz-UPLHBFWStItwzZ-qphQg&usqp=CAU
# Downloaded element [52, 94]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSgZiCuukH9LkiYLN4f4_YDTZ0QQcEWJL7ohA&usqp=CAU
# Downloaded element [52, 95]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQtTZElTE-FKFRizuXbJaxR12A4ew2AyEnFdQ&usqp=CAU
# Downloaded element [52, 97]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSoQprvuyZ2FMeMajushsIBLH26MMp1gnLriQ&usqp=CAU
# Downloaded element [52, 98]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTVq6onupRSjC2QceLlzzgBSeio88Zv59UAtQ&usqp=CAU
# Downloaded element [52, 99]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSVEz1UjIiGHMX68TR97gaQVixcNChRxlol2w&usqp=CAU
# Downloaded element [52, 100]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSAQ7O_b7JIELuHyU3n3RbQwyiQCdzbbMnWHQ&usqp=CAU
# Downloaded element [52, 101]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQr7yrWoOiy7wXCl2imIeKCtXRKho8abXFmbQ&usqp=CAU
# Downloaded element [52, 102]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQQ68NTzEbwK1uBxF3h-IeXI1CPUutukCW_Ig&usqp=CAU
# Downloaded element [52, 103]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpC0krkwg82XumdtZZE-ymFSPExvDWAkvzkA&usqp=CAU
# Downloaded element [52, 104]. URL: https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTKkA53ZjAVpjC1axkdFK5kWqkMNwTEkMooug&usqp=CAU
